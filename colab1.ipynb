# %% [markdown]
# <a href="https://colab.research.google.com/github/mixailxoxlov/yo/blob/main/colab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown
#
#
#
# Нужно сделать:
# 1. Список.
# 2. Рисунок.
# 3. Таблицу.
# 4. Ссылку.
#
# ![изображение_2025-02-19_125317793.png](data:image/png;base64,...)
#
# |  **Имя**      |    **Фамилия**    |   **Группа**   |
# |-----------|:--------------|:-----------|
# |    Илья   |      Цой      |   ЭН1-45   |
# | Александр |   Овчинников   |   ЭН1-42   |
# |  Михаил   |    Хохлов     |   ЭН1-42   |
#
# <a href = "https://skine.ru/articles/246184/"> Ссылка на руководство по Markdown
